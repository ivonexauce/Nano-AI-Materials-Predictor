# %% [markdown]
# # 03 — Model Training
# Step-by-step training of CGCNN on materials data with monitoring.

# %%
import sys
sys.path.insert(0, '..')
# %run -i "../prediction/trainer.py" --data "../data/sample_materials.json" --target bandgap_ev --epochs 50
