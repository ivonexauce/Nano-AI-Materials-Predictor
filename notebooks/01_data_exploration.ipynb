# %% [markdown]
# # 01 — Data Exploration
# Exploring the Materials Project dataset: property distributions, element frequencies, and crystal structures.

# %%
import sys, json, matplotlib.pyplot as plt, seaborn as sns
sys.path.insert(0, '..')
from data.fetcher import load_sample_data
materials = load_sample_data()
print(f'Loaded {len(materials)} materials')
