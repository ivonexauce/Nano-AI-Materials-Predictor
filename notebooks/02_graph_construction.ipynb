# %% [markdown]
# # 02 — Graph Construction
# Visual walkthrough of converting crystal structures into graph representations for GNN input.

# %%
import sys, json
sys.path.insert(0, '..')
from gnn.graph_builder import build_graph
from data.fetcher import load_sample_data
materials = load_sample_data()
graph = build_graph(materials[0])
print(f'Nodes: {graph["n_atoms"]}, Edges: {graph["edge_index"].shape[1]}')
